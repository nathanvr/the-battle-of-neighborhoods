# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### 1.1 Problem Description:
# Changing house isnt a simple task, and much less move from one city to another, you must be clear criteria when choosing house such as nearby places, restaurants, supermarkets, etc.
#
# Andres has a job offer in New York City. he want to accept it but he don't want to change his lifestyle in a significant way. He wants rent in a neighborhood very similar to his neighborhood in Bogota, Colombia.
#
# ### 1.2 Problem Background:
#
# #### Population:
# New York is one of the most populous cities with 8.3 million habitants in an area of 783.8 km2. with great cultural diversity, considered a global city due to its worldwide influence. it has 5 districts (Bronx, Brooklyn, Manhattan, Queens, Staten islands) and 306 neighborhoods.
#
# ### 1.3 Target audience:
# people who want to find a neighborhood to live in new york, this project serves as a guide for anyone who wants to move to NY
#
# ### 1.4 Success Criteria:
# the success criteria of the project will be to make a good recommendation to Andres of the neighborhoods that he can choose to live in New York according to his needs.

# %% [markdown]
# ## 2. Data
#
# Bogota city: To know the coordinates of the neighborhood in which Andres lives, it is not necessary to download an entire data set, just search for the neighborhood in any map service and copy it..<br>
# Neighborhood: el pedregal<br>
# City: Bogota, Colombia<br>
# Coordinates: 4.6841502,-74.0440973<br>
#
# NYC data: The coordinates of the neighborhoods of New York will be acquired from the link provided in the course.<br>
# url = https://geo.nyu.edu/catalog/nyu_2451_34572

# %% [markdown]
# ## 3. Metodology.
#
# To achieve the objetive in this project we desire to split in 3 parts, first we want to distinguish the neighborhood of Andres, it in termns of venues within a radius of 500 mt. after we will analyce the neigborhoods in brookly again in termns of venues, to characterize them and be able to generate a model to group the neighborhoods into different clusters, we will use the kmeans algorithm.

# %% [markdown]
# ### 3.1 Analisys of pedregal in Bogota city.
# To obtain the data of el pedregal we ask to Andres for the location of his house. from this point we will start the analisys of his neighborhood using the service of Foursquare.
#
# #### Map of El Pedregal, Bogota Colombia:
# ![el%20pedregal%20map.jpg](attachment:el%20pedregal%20map.jpg)
#
# #### location description
# after we make a request to Foursquare we can see the venues near to the point and this venues will be grouped by frecuency to distinguish the neigborhood. this data frame has 42 variables this information is relevant if we want to cluster this neighborhood.
#
# ![predregal_frecuency.png](attachment:predregal_frecuency.png)
#
#
# ### 3.2 Analisys and clustering of neighborhoods in Brooklyn
# in brooklyn exist 70 neighborhoods, and we use the same method to classified all the neighborhoods.
#
# ![Brookly_frecuency.png](attachment:Brookly_frecuency.png)
#
# there are 290 venues in the neighborhood, so it is important to unify the shape of data sets with the same number of variables. from the 42 variables in el pedregal 6 isnt in the variables of brooklyn. so to avoid problemns we drop this 6 variables. adicionally we agregate the others to complete 290 variables with value 0.
#
# #### clusters:
# once we have the characterization of the neighborhoods we can cluster all the neigbourhood. we select a k = 6.
#
# continue we can see a map of the clusters
#
# ![clusters_mapa.png](attachment:clusters_mapa.png)

# %% [markdown]
# ## 4. Results

# %% [markdown]
# the next table is the list of neighborhoods that are similar to el pedregal. once we use the model trained, the result was Cluster No 5
#
# ![resultados.png](attachment:resultados.png)

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# there are too much neighborhoods in brooklyn similar to el pedregal, since it is an urban zone.
#
# te model can be improve using another variable like security, additionally compare wit the Hierarchical algorithm.
